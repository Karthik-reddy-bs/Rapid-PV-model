# %% [markdown]
# # Panel Distribution Algorithm:
#
# is used to geometrically place PV panels on rooftop segments considering the slope, aspect and geometry of rooftop segments.

# %% [markdown]
# # Prerequisite script
#
# Attribute Table.ipynb

# %%
import os, sys
import ogr
from math import ceil
import numpy as np;
import pandas as pd
import geopandas as gpd
import math
import shapely
import operator
from shapely.ops import cascaded_union
from itertools import chain
import time
from shapely.geos import TopologicalError

# %%
    """
    Main Input parameters for the PDA:
    -----------------
    
    The primary input for this algorithm is an attribute table in the form of a shapefile, 
    which consists of rooftop segment ID, geometry of rooftop segment, slope and aspect of the rooftop segment
    
    shapefile    : Output from "Attribute Table.ipynb" which contains rooftop segments slope, aspect, geometry and segment ID.
    crs          : co-ordinate reference system of the shapefile
    d            : Panel row spacing, can be optimized according to technical & Economical parameters
    β_o          : Optimal slope of PV panels on flat rooftops, can be optimized according to location
            
    panel_length : Length of PV panel, according to the specification
    panel_width  : Width of PV panel, according to the specification
    
    Note: Sample input files and parameters can be found under the folder "Datasets" in Github
        
    """

shapefile      = gpd.read_file("segments.shp")
crs            = "EPSG:25833"
d              = 1.5 
β_o            = 53 
panel_length   = 1.6 
panel_width    = 1

# %%
# Temporary and output locations of the shapefiles.

temp_loc = "temp.shp"
output_loc = "pv_panels.shp"

# %%
# split the shapefile dataframe into individual rows and sets the crs

splits = [shapefile.loc[[i]] for i in shapefile.index]

gdf = gpd.GeoDataFrame(crs=crs)
# Out:
# <ipython-input-4-f34ec55b6a7a>:5: FutureWarning: Assigning CRS to a GeoDataFrame without a geometry column is now deprecated and will not be supported in the future.
#   gdf = gpd.GeoDataFrame(crs=crs)

# %%
def fishnet(poly, count, aspect_polygon, mode, slope, d, num=0):
    
    """
    Input Parameters:
    -----------------
    
        poly           : Rooftop segment polygon
        count          : To count the PV panels
        aspect_polygon : Orientation of the rooftop segment (0 - 360 deg)
        mode           : Landscape or portrait mode
        slope          : Slope of rooftop segment
        num            : mode (0 - default, 1 - portrait, 2- landscape)
        
    Returns
    -------
    
        PV panel placement on rooftop segment.
        
    """
    # To get rectangular bounds of the polygon for creating the fishnet grid

    bounds2                = poly.bounds
    xmin, ymin, xmax, ymax = bounds2
    
    
    def main(outputGridfn, xmin, xmax, ymin, ymax, gridHeight, gridWidth, slope, d):
        
        """
        Input Parameters:
        ----------------

            outputGridfn           : Location of output file.
            xmin, xmax, ymin, ymax : Bounds of the rooftop segment polygon
            gridHeight             : Length of PV panel
            gridWidth              : Width of PV panel
            slope                  : Slope of rooftop segment

        Returns
        -------
            Fishnet grid according to the slope and module row spacing of the rooftop segment.

        """
    
        # convert bounds to float
        
        diff1 = float(xmax) - float(xmin)
        diff2 = float(ymax) - float(ymin)
        
        # Creating the boundary rectangle for fishnet grid
        
        if diff1 > diff2:
            
            xmin = float(xmin) - 5
            xmax = float(xmax) + 5
            ymin = float(ymin) - (diff1)
            ymax = float(ymax) + (diff1)
            
        else:
            xmin = float(xmin) - (diff2)
            xmax = float(xmax) + (diff2)
            ymin = float(ymin) - 5
            ymax = float(ymax) + 5
    
        gridWidth  = float(gridWidth)
        gridHeight = float(gridHeight)
        
        # get rows
        rows = ceil((ymax-ymin)/gridHeight)
        
        # get columns
        cols = ceil((xmax-xmin)/gridWidth)
        
        # start grid cell envelope
        ringXleftOrigin   = xmin
        ringXrightOrigin  = xmin + gridWidth
        ringYtopOrigin    = ymax
        ringYbottomOrigin = ymax-gridHeight
    
        # create output file
        outDriver = ogr.GetDriverByName('ESRI Shapefile')
        if os.path.exists(outputGridfn):
            os.remove(outputGridfn)
        outDataSource = outDriver.CreateDataSource(outputGridfn)
        outLayer      = outDataSource.CreateLayer(outputGridfn, geom_type=ogr.wkbPolygon)
        featureDefn   = outLayer.GetLayerDefn()
    
        # create grid cells
        countrows = 0
        while countrows < rows:
            countrows += 1
    
            # reset envelope for rows
            ringXleft = ringXleftOrigin
            ringXright = ringXrightOrigin
            
            countcols = 0
    
            while countcols < cols:
                countcols += 1
                ring = ogr.Geometry(ogr.wkbLinearRing)
                ring.AddPoint(ringXleft, ringYtopOrigin)
                ring.AddPoint(ringXright, ringYtopOrigin)
                ring.AddPoint(ringXright, ringYbottomOrigin)
                ring.AddPoint(ringXleft, ringYbottomOrigin)
                ring.AddPoint(ringXleft, ringYtopOrigin)
                poly = ogr.Geometry(ogr.wkbPolygon)
                poly.AddGeometry(ring)
    
                # add new geom to layer
                outFeature = ogr.Feature(featureDefn)
                outFeature.SetGeometry(poly)
                outLayer.CreateFeature(outFeature)
                outFeature.Destroy
    
                # new envelope for next poly
                
                ringXleft  = ringXleft + gridWidth
                ringXright = ringXright + gridWidth
    
            # new envelope for next poly
            if slope == β_o:
                
                ringYtopOrigin    = ringYtopOrigin - gridHeight - d
                ringYbottomOrigin = ringYbottomOrigin - gridHeight - d
                
            else:
                
                ringYtopOrigin    = ringYtopOrigin - gridHeight
                ringYbottomOrigin = ringYbottomOrigin - gridHeight
    
        # Close DataSources
        outDataSource.Destroy()
    
    
    
    if __name__ == "__main__":
            
        outfp = temp_loc
        area  = mode[0] * mode[1]
        main(outfp, xmin, xmax, ymin, ymax, mode[1], mode[0], slope, d)
    
   # stores the fishnet grid as a temporary shapefile "temp.shp" 
    temp     = gpd.read_file("temp.shp")
    temp.crs = crs

    # Rotating the fishnet grid according to the aspect of the rooftop segment
    a = list(chain(*list(temp.loc[0, 'geometry'].centroid.coords)))
    b = list(chain(*list(temp.loc[temp.shape[0] - 1, 'geometry'].centroid.coords)))
    c = np.average(np.array([a, b]), axis=0)
    
    for index, row in temp.iterrows():
        
        rotated = shapely.affinity.rotate(row['geometry'], 180 + aspect_polygon, (c[0], c[1]))
        temp.loc[index, 'geometry'] = rotated
    
    # Translates the fishnet grid horizontally to accomodate more PV panels
    opt_x = {}
    for x in np.arange(0,mode[1],0.1):
        
        shift_x = temp.translate(x * round(math.cos(math.radians(180 + aspect_polygon)), 2), x * round(math.sin(math.radians(180 + aspect_polygon)), 2))
        shift_x.to_file("shifttemp.shp")
        shifttemp     = gpd.read_file("shifttemp.shp")
        shifttemp.crs = crs
        
        try:
            
            res_intersection = gpd.overlay(polygon_df, shifttemp, how='intersection')
            splits1          = [res_intersection.loc[[i]] for i in res_intersection.index]
            
            for i in res_intersection.index:
                
                polygon_df1 = splits1[i]
                poly3       = polygon_df1.loc[i, 'geometry']
                poly3.crs   = crs
                res_intersection.loc[i, 'pv_area'] = poly3.area
            
            ful_polygon = res_intersection[res_intersection['pv_area'] > area-0.01]
            opt_x[x]    = ful_polygon.shape[0]
            
        except TopologicalError:
            
            pass
    
    opt_x = max(opt_x.items(), key=operator.itemgetter(1))[0]
    shift = temp.translate(opt_x * round(math.cos(math.radians(180 + aspect_polygon)), 2),\
                           opt_x * round(math.sin(math.radians(180 + aspect_polygon)), 2))
    
    # Translates the fishnet grid vertically to accomodate more PV panels
    opt_y = {}
    for y in np.arange(0,mode[0],0.2):
        
        shift_y = shift.translate(y * round(math.cos(math.radians(90 + 180 + aspect_polygon)), 2),\
                                  y * round(math.sin(math.radians(90 + 180 + aspect_polygon)), 2))
        shift_y.to_file("shifttemp.shp")
        shifttemp     = gpd.read_file("shifttemp.shp")
        shifttemp.crs = crs
        
        try:
            
            res_intersection = gpd.overlay(polygon_df, shifttemp, how='intersection')
            splits1          = [res_intersection.loc[[i]] for i in res_intersection.index]
            
            for i in res_intersection.index:
                
                polygon_df1 = splits1[i]
                poly3       = polygon_df1.loc[i, 'geometry']
                poly3.crs   = crs
                res_intersection.loc[i, 'pv_area'] = poly3.area
            
            ful_polygon = res_intersection[res_intersection['pv_area'] > area-0.01]
            opt_y[y]    = ful_polygon.shape[0]

        except TopologicalError:
            
            pass
    
    opt_y = max(opt_y.items(), key=operator.itemgetter(1))[0]
    
    # Stores the best possible location of fishnet grid in a temporary file for PV slicing
    shifted = shift.translate(opt_y * round(math.cos(math.radians(90 + 180 + aspect_polygon)), 2),\
                              opt_y * round(math.sin(math.radians(90 + 180 + aspect_polygon)), 2))
    shifted.to_file("shifttemp.shp")
    shifttemp     = gpd.read_file("shifttemp.shp")
    shifttemp.crs = crs
    
    # PV panel slicing is done by intersecting the rooftop segment polygon with the fishnet grid.
    # Sometimes the vector datasets have topological errors due to intersection of multiple polygons and linestrings.
    
    try:
        
        res_intersection = gpd.overlay(polygon_df, shifttemp, how='intersection')
        splits1          = [res_intersection.loc[[i]] for i in res_intersection.index]
        
        for i in res_intersection.index:
            
            polygon_df1 = splits1[i]
            poly3       = polygon_df1.loc[i, 'geometry']
            poly3.crs   = crs
            res_intersection.loc[i, 'pv_area'] = poly3.area
        
        ful_polygon = res_intersection[res_intersection['pv_area'] > area-0.01]
        count[num]  = ful_polygon.shape[0]
        return ful_polygon

    except TopologicalError:
        
        pass

# %%
for i in range(shapefile.shape[0]):
    
    print(f'Processing now segment_id:{i}/{shapefile.shape[0]}')
    balance    = 1 # Checks whether any balance panels could be extracted from the rooftop segment or not
    polygon_df = splits[i]
    slope      = polygon_df.loc[i, 'Slope']
    aspect_polygon = polygon_df.loc[i, 'Seg_Aspect']
    
    # Orthogonal projection of Length and width of PV panel accoding to the slope and arrangement (landscape or portrait)
    length1  = round(math.cos(math.radians(slope)), 2) * panel_length
    width1   = panel_width
    portrait = [length1, width1]

    width2    = round(math.cos(math.radians(slope)), 2) * panel_width
    length2   = panel_length
    landscape = [length2, width2]
    
    while balance != 0:
        
        poly2     = polygon_df.loc[i, 'geometry']
        poly2.crs = crs
        count     = {}
        
        # Fishnet grid in portrait mode
        fishnet(poly2, count, aspect_polygon, portrait, slope, d, 1)
        # Fishnet grid in landscape mode
        fishnet(poly2, count, aspect_polygon, landscape, slope, d, 2)
        
        # Checks in which mode, more number of PV panels can be placed on rooftop segment
        try:
            
            highest_mode = max(count.items(), key=operator.itemgetter(1))[0]
            balance      = max(count.items(), key=operator.itemgetter(1))[1]
            
        except:
            
            balance = 0
        
        # Checks if there is no space on the rooftop segment for a PV panel and breaks the iteration
        if balance == 0:
            
            break
            
        # Performs PV panel slicing according to the highest mode
        if highest_mode == 1:
            
            pvp_full = fishnet(poly2, count, aspect_polygon, portrait, slope, d)
            
        else:
            
            pvp_full = fishnet(poly2, count, aspect_polygon, landscape, slope, d)
            
        # Joins the PV panels together that belongs to a rooftop segment
        gdf = gpd.GeoDataFrame(pd.concat([gdf, pvp_full], ignore_index=True))
        
        # Checks for duplicate PV panel geometries and breaks the iteration
        if not gdf["geometry"].is_unique:
            
            break
    
        try:
            
            polygon_df = gpd.overlay(polygon_df, pvp_full, how='difference')
            
        except TopologicalError:
            
            break
            
        # Checks if rooftop polygon can accomodate anymore PV panels and breaks the iteration
        if polygon_df.empty or slope == β_o:
            
            break
# Out:
# Processing now segment_id:0/803
# Processing now segment_id:1/803
# Processing now segment_id:2/803
# Processing now segment_id:3/803
# Processing now segment_id:4/803
# Processing now segment_id:5/803
# Processing now segment_id:6/803
# Processing now segment_id:7/803
# Processing now segment_id:8/803
# Processing now segment_id:9/803
# Processing now segment_id:10/803
# Processing now segment_id:11/803
# Processing now segment_id:12/803
# Processing now segment_id:13/803
# Processing now segment_id:14/803
# Processing now segment_id:15/803
# Processing now segment_id:16/803
# Processing now segment_id:17/803
# Processing now segment_id:18/803
# Processing now segment_id:19/803
# Processing now segment_id:20/803
# Processing now segment_id:21/803
# Processing now segment_id:22/803
# Processing now segment_id:23/803
# Processing now segment_id:24/803
# Processing now segment_id:25/803
# Processing now segment_id:26/803
# Processing now segment_id:27/803
# Processing now segment_id:28/803
# Processing now segment_id:29/803
# Processing now segment_id:30/803
# Processing now segment_id:31/803
# Processing now segment_id:32/803
# Processing now segment_id:33/803
# Processing now segment_id:34/803
# Processing now segment_id:35/803
# Processing now segment_id:36/803
# Processing now segment_id:37/803
# Processing now segment_id:38/803
# Processing now segment_id:39/803
# Processing now segment_id:40/803
# Processing now segment_id:41/803
# Processing now segment_id:42/803
# Processing now segment_id:43/803
# Processing now segment_id:44/803
# Processing now segment_id:45/803
# Processing now segment_id:46/803
# Processing now segment_id:47/803
# Processing now segment_id:48/803
# Processing now segment_id:49/803
# Processing now segment_id:50/803
# Processing now segment_id:51/803
# Processing now segment_id:52/803
# Processing now segment_id:53/803
# Processing now segment_id:54/803
# Processing now segment_id:55/803
# Processing now segment_id:56/803
# Processing now segment_id:57/803
# Processing now segment_id:58/803
# Processing now segment_id:59/803
# Processing now segment_id:60/803
# Processing now segment_id:61/803
# Processing now segment_id:62/803
# Processing now segment_id:63/803
# Processing now segment_id:64/803
# Processing now segment_id:65/803
# Processing now segment_id:66/803
# Processing now segment_id:67/803
# Processing now segment_id:68/803
# Processing now segment_id:69/803
# Processing now segment_id:70/803
# Processing now segment_id:71/803
# Processing now segment_id:72/803
# Processing now segment_id:73/803
# Processing now segment_id:74/803
# Processing now segment_id:75/803
# Processing now segment_id:76/803
# Processing now segment_id:77/803
# Processing now segment_id:78/803
# Processing now segment_id:79/803
# Processing now segment_id:80/803
# Processing now segment_id:81/803
# Processing now segment_id:82/803
# Processing now segment_id:83/803
# Processing now segment_id:84/803
# Processing now segment_id:85/803
# Processing now segment_id:86/803
# Processing now segment_id:87/803
# Processing now segment_id:88/803
# Processing now segment_id:89/803
# Processing now segment_id:90/803
# Processing now segment_id:91/803
# Processing now segment_id:92/803
# Processing now segment_id:93/803
# Processing now segment_id:94/803
# Processing now segment_id:95/803
# Processing now segment_id:96/803
# Processing now segment_id:97/803
# Processing now segment_id:98/803
# Processing now segment_id:99/803
# Processing now segment_id:100/803
# Processing now segment_id:101/803
# Processing now segment_id:102/803
# Processing now segment_id:103/803
# Processing now segment_id:104/803
# Processing now segment_id:105/803
# Processing now segment_id:106/803
# Processing now segment_id:107/803
# Processing now segment_id:108/803
# Processing now segment_id:109/803
# Processing now segment_id:110/803
# Processing now segment_id:111/803
# Processing now segment_id:112/803
# Processing now segment_id:113/803
# Processing now segment_id:114/803
# Processing now segment_id:115/803
# Processing now segment_id:116/803
# Processing now segment_id:117/803
# Processing now segment_id:118/803
# Processing now segment_id:119/803
# Processing now segment_id:120/803
# Processing now segment_id:121/803
# Processing now segment_id:122/803
# Processing now segment_id:123/803
# Processing now segment_id:124/803
# Processing now segment_id:125/803
# Processing now segment_id:126/803
# Processing now segment_id:127/803
# Processing now segment_id:128/803
# Processing now segment_id:129/803
# Processing now segment_id:130/803
# Processing now segment_id:131/803
# Processing now segment_id:132/803
# Processing now segment_id:133/803
# Processing now segment_id:134/803
# Processing now segment_id:135/803
# Processing now segment_id:136/803
# Processing now segment_id:137/803
# Processing now segment_id:138/803
# Processing now segment_id:139/803
# Processing now segment_id:140/803
# Processing now segment_id:141/803
# Processing now segment_id:142/803
# Processing now segment_id:143/803
# Processing now segment_id:144/803
# Processing now segment_id:145/803
# Processing now segment_id:146/803
# Processing now segment_id:147/803
# Processing now segment_id:148/803
# Processing now segment_id:149/803
# Processing now segment_id:150/803
# Processing now segment_id:151/803
# Processing now segment_id:152/803
# Processing now segment_id:153/803
# Processing now segment_id:154/803
# Processing now segment_id:155/803
# Processing now segment_id:156/803
# Processing now segment_id:157/803
# Processing now segment_id:158/803
# Processing now segment_id:159/803
# Processing now segment_id:160/803
# Processing now segment_id:161/803
# Processing now segment_id:162/803
# Processing now segment_id:163/803
# Processing now segment_id:164/803
# Processing now segment_id:165/803
# Processing now segment_id:166/803
# Processing now segment_id:167/803
# Processing now segment_id:168/803
# Processing now segment_id:169/803
# Processing now segment_id:170/803
# Processing now segment_id:171/803
# Processing now segment_id:172/803
# Processing now segment_id:173/803
# Processing now segment_id:174/803
# Processing now segment_id:175/803
# Processing now segment_id:176/803
# Processing now segment_id:177/803
# Processing now segment_id:178/803
# Processing now segment_id:179/803
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-c5048d28dc4a> in <module>
#      25         fishnet(poly2, count, aspect_polygon, portrait, slope, d, 1)
#      26         # Fishnet grid in landscape mode
# ---> 27         fishnet(poly2, count, aspect_polygon, landscape, slope, d, 2)
#      28
#      29         # Checks in which mode, more number of PV panels can be placed on rooftop segment
#
# <ipython-input-8-cc9f2fd5367e> in fishnet(poly, count, aspect_polygon, mode, slope, d, num)
#     158     for x in np.arange(0,mode[1],0.1):
#     159
# --> 160         shift_x = temp.translate(x * round(math.cos(math.radians(180 + aspect_polygon)), 2), x * round(math.sin(math.radians(180 + aspect_polygon)), 2))
#     161         shift_x.to_file("shifttemp.shp")
#     162         shifttemp     = gpd.read_file("shifttemp.shp")
#
# ~\anaconda3\lib\site-packages\geopandas\base.py in translate(self, xoff, yoff, zoff)
#     728             dimensions respectively.
#     729         """  # noqa (E501 link is longer than max line length)
# --> 730         return _delegate_geo_method("translate", self, xoff, yoff, zoff)
#     731
#     732     def rotate(self, angle, origin="center", use_radians=False):
#
# ~\anaconda3\lib\site-packages\geopandas\base.py in _delegate_geo_method(op, this, *args, **kwargs)
#      87
#      88     a_this = GeometryArray(this.geometry.values)
# ---> 89     data = getattr(a_this, op)(*args, **kwargs).data
#      90     return GeoSeries(data, index=this.index, crs=this.crs)
#      91
#
# ~\anaconda3\lib\site-packages\geopandas\array.py in translate(self, xoff, yoff, zoff)
#     624     def translate(self, xoff=0.0, yoff=0.0, zoff=0.0):
#     625         return GeometryArray(
# --> 626             vectorized._affinity_method("translate", self.data, xoff, yoff, zoff),
#     627             crs=self.crs,
#     628         )
#
# ~\anaconda3\lib\site-packages\geopandas\_vectorized.py in _affinity_method(op, left, *args, **kwargs)
#     429             res = geom
#     430         else:
# --> 431             res = getattr(shapely.affinity, op)(geom, *args, **kwargs)
#     432         out.append(res)
#     433     data = np.empty(len(left), dtype=object)
#
# ~\anaconda3\lib\site-packages\shapely\affinity.py in translate(geom, xoff, yoff, zoff)
#     255         \ 0  0  0   1  /
#     256     """
# --> 257     if geom.is_empty:
#     258         return geom
#     259     matrix = (1.0, 0.0, 0.0,
#
# ~\anaconda3\lib\site-packages\shapely\geometry\base.py in is_empty(self)
#     697     def is_empty(self):
#     698         """True if the set of points in this geometry is empty, else False"""
# --> 699         return (self._geom is None) or bool(self.impl['is_empty'](self))
#     700
#     701     @property
#
# ~\anaconda3\lib\site-packages\shapely\predicates.py in __call__(self, this)
#      23     def __call__(self, this):
#      24         self._validate(this)
# ---> 25         return self.fn(this._geom)
#
# ~\anaconda3\lib\site-packages\shapely\geos.py in errcheck_predicate(result, func, argtuple)
#     560
#     561
# --> 562 def errcheck_predicate(result, func, argtuple):
#     563     """Result is 2 on exception, 1 on True, 0 on False"""
#     564     if result == 2:
#
# KeyboardInterrupt:

# %%
outfp = output_loc
gdf.to_file(r"panels_grid1.shp")
print("Finished placing panels and panels.shp file is generated")
